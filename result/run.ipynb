# %%
from two_vortices import *
# Out:
# Active vortex indices: [np.int64(215), np.int64(225)]
# Active vortex positions: [[-0.5  0. ]
#  [ 0.5  0. ]]

# %%
from one_wall import *
# Out:
# Coarse grid shape: (16, 7, 2), points: 112
# Fine grid shape: (31, 3, 2), points: 93
# * Number of vortices in coarse grid: 112
# * Number of vortices in fine grid: 93
# Simulating vortex trajectories for X and Y ...
# Vortex trajectory simulation time: 433.75 seconds
# Background velocity magnitude range: min=0.0000, max=1.1387
# Saved streamline image at t=0.00 to figure/one_wall/streamlines_t00.00.png
# Saved streamline image at t=4.00 to figure/one_wall/streamlines_t04.00.png
# Saved streamline image at t=8.00 to figure/one_wall/streamlines_t08.00.png
# Saved streamline image at t=12.00 to figure/one_wall/streamlines_t12.00.png
# Saved streamline image at t=16.00 to figure/one_wall/streamlines_t16.00.png
# Saved streamline image at t=20.00 to figure/one_wall/streamlines_t20.00.png

# %%
from corner import *
# Out:
# Coarse grid: 10 x 10 = 100 points
# Region A (Dbxy): 4 x 4 = 16 points
# Region B (Dbx): 19 x 4 = 76 points
# Region C (Dby): 4 x 19 = 76 points
# Computing vortex trajectories......
# Vortex trajectories computed in 240.15 seconds
# Saved streamline image at t=0.00 to figure/corner/streamlines_t00.00.png
# Saved streamline image at t=4.00 to figure/corner/streamlines_t04.00.png
# Saved streamline image at t=8.00 to figure/corner/streamlines_t08.00.png
# Saved streamline image at t=12.00 to figure/corner/streamlines_t12.00.png
# Saved streamline image at t=16.00 to figure/corner/streamlines_t16.00.png
# Saved streamline image at t=20.00 to figure/corner/streamlines_t20.00.png

# %%
from belt import *

# %%
# from klein import *
