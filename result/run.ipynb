# %%
from two_vortices import *
# Out:
# Active vortex indices: [np.int64(215), np.int64(225)]
# Active vortex positions: [[-0.5  0. ]
#  [ 0.5  0. ]]
# Animation saved at: animation/velocity_field_same.mp4
# Animation saved at: animation/velocity_field_opposite.mp4

# %%
from one_wall import *

# %%
from corner import *
# Out:
# Coarse grid: 8 x 8 = 64 points
# Region A (Dbxy): 2 x 2 = 4 points
# Region B (Dbx): 15 x 2 = 30 points
# Region C (Dby): 2 x 15 = 30 points
# * Number of vortices in coarse grid: 64
# * Number of vortices in Region A: 4
# * Number of vortices in Region B: 30
# * Number of vortices in Region C: 30
# Computing vortex trajectories......
# Vortex trajectories computed in 55.89 seconds
# Simulating boats starting from grid points......
# Boat simulation completed in 40.89 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from corner import *
#
# File ~/Documents/2024-2025_OxfordSPC/6_dissertation/code/result/corner.py:395
#     393 save_path = os.path.join("animation", "velocity_field.mp4")
#     394 writer = FFMpegWriter(fps=25)
# --> 395 anim.save(save_path, writer=writer)
#     396 print(f"Velocity field animation saved at: {save_path}")
# ...

# %%
from belt import *
# Out:
# Lower Fine grid shape: (16, 2, 2), number of points: 32
# Upper Fine grid shape: (16, 2, 2), number of points: 32
# Coarse grid shape: (13, 3, 2), number of points: 39
# * Number of vortices (total): 103
# Computing vortex trajectories......
# Time for trajectory computation: 26.70 seconds
# Simulating vortex boats......
# Lower Fine grid shape: (16, 2, 2), number of points: 32
# Upper Fine grid shape: (16, 2, 2), number of points: 32
# Coarse grid shape: (13, 3, 2), number of points: 39
# Time for boat simulation: 26.68 seconds
# Lower Fine grid shape: (16, 2, 2), number of points: 32
# Upper Fine grid shape: (16, 2, 2), number of points: 32
# Coarse grid shape: (13, 3, 2), number of points: 39
# Animation saved at: animation/belt_domain.mp4

# %%
# from klein import *
# Out:
# Region D: 64 points, D₁: 16 points, D₂: 16 points, D₃: 16 points, D₄: 16 points
# Animation saved at: animation/2d_3d_klein.mp4
