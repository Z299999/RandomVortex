# %%
from two_vortex_dif import *
# Out:
# Active vortex indices: [np.int64(215), np.int64(225)]
# Active vortex positions: [[-0.5  0. ]
#  [ 0.5  0. ]]
# Animation saved at: animation/velocity_field_opposite.mp4

# %%
from two_vortex_same import *
# Out:
# Active vortex indices: [np.int64(215), np.int64(225)]
# Active vortex positions: [[-0.5  0. ]
#  [ 0.5  0. ]]
# Animation saved at: animation/velocity_field_same.mp4

# %%
from one_wall import *
# Out:
# Coarse grid shape: (13, 6, 2), points: 78
# Fine grid shape: (25, 2, 2), points: 50
# * Number of vortices in coarse grid: 78
# * Number of vortices in fine grid: 50
# Simulating vortex trajectories for X and Y ...

# %%
from corner import *

# %%
from belt import *
